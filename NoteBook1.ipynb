# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %% [markdown]
# # Importing Dataset

# %%
sales = pd.read_csv("C:\\Users\\2102780\\OneDrive - Cognizant\\Desktop\\Sales_df.csv")

# %%
inventory =pd.read_excel("C:\\Users\\2102780\\OneDrive - Cognizant\\Desktop\\Hackathon\\inventory_df.xlsx")

# %%
#seeing top 5 rows in dataset 
sales.head()
# Out:
#    Unnamed: 0  country_cd channel                   customer  \
# 0           0          12   OTHER                Heiko Zobel
# 1           1          15  DIRECT     Theres Trommler B.Eng.
# 2           2          12  DIRECT     Dr. Helena Wähner MBA.
# 3           3          13  DIRECT      Sylke Mülichen B.Eng.
# 4           4          10   OTHER  Univ.Prof. Angelique Koch
#
#    inventory_location SKU_Number transaction_date sales_typ  sales_qty  \
# 0                  98   38753-97       09-07-2021    Return       7607
# 1                  93   70339-30       08-06-2021    Return       3430
# 2                  98   28088-72       08-09-2021    Return       4081
# 3                  93   10785-85       26-09-2021    Return        592
# 4                  93   17101-76       10-12-2021    Return       8745
#
#   local_crncy  ...  cust_nbr  prod_grp  batch_lot_nbr qty_ordr  ordr_typ  \
# 0         INR  ...   5504746       NaN      GN5I67CC8     7607       NaN
# ...

# %%
#seeing bottom top rows 
sales.tail()
# Out:
#         Unnamed: 0  country_cd channel              customer  \
# 999995      999995          14  DIRECT       Waldemar Jopich
# 999996      999996          11   OTHER     Aneta Ernst B.Sc.
# 999997      999997          12   OTHER  Ing. Giuseppina Trub
# 999998      999998          13   OTHER  Edward Freudenberger
# 999999      999999          15   OTHER     Prof. Gerti Löwer
#
#         inventory_location SKU_Number transaction_date sales_typ  sales_qty  \
# 999995                  95   82151-13       31-05-2021     Sales       7760
# 999996                  98   27075-15       12-04-2021    Return       1875
# 999997                  98   40555-10       23-01-2021     Sales       2588
# 999998                  92   70962-54       28-03-2021     Sales       8592
# 999999                  96   51766-48       12-12-2021    Return       1682
#
#        local_crncy  ...  cust_nbr  prod_grp  batch_lot_nbr qty_ordr  ordr_typ  \
# ...

# %%
#viewing the shape of the data 
sales.shape
# Out:
# (1000000, 31)

# %%
#seeing the total data in the dataset
sales.size
# Out:
# 31000000

# %%
#shows the info abt the whole dataset
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 31 columns):
#  #   Column              Non-Null Count    Dtype
# ---  ------              --------------    -----
#  0   Unnamed: 0          1000000 non-null  int64
#  1   country_cd          1000000 non-null  int64
#  2   channel             1000000 non-null  object
#  3   customer            1000000 non-null  object
#  4   inventory_location  1000000 non-null  int64
#  5   SKU_Number          1000000 non-null  object
#  6   transaction_date    1000000 non-null  object
#  7   sales_typ           1000000 non-null  object
#  8   sales_qty           1000000 non-null  int64
#  9   local_crncy         1000000 non-null  object
#  10  sls_val_loc_crncy   1000000 non-null  int64
#  11  src_sls_usd         1000000 non-null  float64
#  12  whse_cntry_cd       1000000 non-null  int64
#  13  ship_whse_cd        999999 non-null   object
#  14  sls_cntry_cd        1000000 non-null  int64
# ...

# %%
#showing the dataset count ,min,max,std,percentile
sales.describe()
# Out:
#            Unnamed: 0      country_cd  inventory_location       sales_qty  \
# count  1000000.000000  1000000.000000      1000000.000000  1000000.000000
# mean    499999.500000       12.501046           94.506525     4997.928996
# std     288675.278933        1.708236            2.871874     2884.825498
# min          0.000000       10.000000           90.000000        1.000000
# 25%     249999.750000       11.000000           92.000000     2501.000000
# 50%     499999.500000       13.000000           95.000000     5001.000000
# 75%     749999.250000       14.000000           97.000000     7493.000000
# max     999999.000000       15.000000           99.000000    10000.000000
#
#        sls_val_loc_crncy     src_sls_usd   whse_cntry_cd    sls_cntry_cd  \
# count     1000000.000000  1000000.000000  1000000.000000  1000000.000000
# mean       499898.209579     6248.727620       94.506525       94.506525
# std        288616.691291     3607.708641        2.871874        2.871874
# ...

# %%
sales.head()
# Out:
#    Unnamed: 0  country_cd channel                   customer  \
# 0           0          12   OTHER                Heiko Zobel
# 1           1          15  DIRECT     Theres Trommler B.Eng.
# 2           2          12  DIRECT     Dr. Helena Wähner MBA.
# 3           3          13  DIRECT      Sylke Mülichen B.Eng.
# 4           4          10   OTHER  Univ.Prof. Angelique Koch
#
#    inventory_location SKU_Number transaction_date sales_typ  sales_qty  \
# 0                  98   38753-97       09-07-2021    Return       7607
# 1                  93   70339-30       08-06-2021    Return       3430
# 2                  98   28088-72       08-09-2021    Return       4081
# 3                  93   10785-85       26-09-2021    Return        592
# 4                  93   17101-76       10-12-2021    Return       8745
#
#   local_crncy  ...  cust_nbr  prod_grp  batch_lot_nbr qty_ordr  ordr_typ  \
# 0         INR  ...   5504746       NaN      GN5I67CC8     7607       NaN
# ...

# %%
#showing is there any null value in the dataset
sales.isnull()
# Out:
#         Unnamed: 0  country_cd  channel  customer  inventory_location  \
# 0            False       False    False     False               False
# 1            False       False    False     False               False
# 2            False       False    False     False               False
# 3            False       False    False     False               False
# 4            False       False    False     False               False
# ...            ...         ...      ...       ...                 ...
# 999995       False       False    False     False               False
# 999996       False       False    False     False               False
# 999997       False       False    False     False               False
# 999998       False       False    False     False               False
# 999999       False       False    False     False               False
#
#         SKU_Number  transaction_date  sales_typ  sales_qty  local_crncy  ...  \
# ...

# %%
#dropping unnamed column in dataset

sales.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#checking null values in the prod grp

sales['prod_grp'].isnull().sum()
# Out:
# 1000000

# %%
#dropping the prod grp column in dataset 

sales.drop('prod_grp',axis=1,inplace=True)

# %%
#after duplicates removal seeing the data is removed or not 
sales.head(2)
# Out:
#    country_cd channel                customer  inventory_location SKU_Number  \
# 0          12   OTHER             Heiko Zobel                  98   38753-97
# 1          15  DIRECT  Theres Trommler B.Eng.                  93   70339-30
#
#   transaction_date sales_typ  sales_qty local_crncy  sls_val_loc_crncy  ...  \
# 0       09-07-2021    Return       7607         INR              49580  ...
# 1       08-06-2021    Return       3430         INR             950966  ...
#
#    cust_catg_lvl2  cust_nbr batch_lot_nbr  qty_ordr  ordr_typ  ordr_nbr  \
# 0             NaN   5504746     GN5I67CC8      7607       NaN  24067685
# 1             NaN   2481490     4YY6L303W      3430       NaN  59779829
#
#   ordr_line_nbr  req_ship_dt  ordr_create_dt  create_date
# 0           NaN   10-07-2021      09-07-2021      49:13.0
# 1           NaN   13-06-2021      08-06-2021      49:13.1
#
# [2 rows x 29 columns]

# %%
#showing all columns in the dataset 

sales.columns
# Out:
# Index(['country_cd', 'channel', 'customer', 'inventory_location', 'SKU_Number',
#        'transaction_date', 'sales_typ', 'sales_qty', 'local_crncy',
#        'sls_val_loc_crncy', 'src_sls_usd', 'whse_cntry_cd', 'ship_whse_cd',
#        'sls_cntry_cd', 'frc_cd', 'consign_cntry', 'shipto_cntry', 'cust_catg',
#        'cust_catg_lvl1', 'cust_catg_lvl2', 'cust_nbr', 'batch_lot_nbr',
#        'qty_ordr', 'ordr_typ', 'ordr_nbr', 'ordr_line_nbr', 'req_ship_dt',
#        'ordr_create_dt', 'create_date'],
#       dtype='object')

# %%
#checkking the null values in the dataset ordr typ column 

sales['ordr_typ'].isnull().count()
# Out:
# 1000000

# %%
#droping the ordr type column in the dataset

sales.drop('ordr_typ',axis=1,inplace=True)

# %%
#checking the null value present in ordr line nbr column

sales['ordr_line_nbr'].isnull().sum()
# Out:
# 1000000

# %%
#droping the order line nbr column 

sales.drop('ordr_line_nbr',axis=1,inplace=True)

# %%
sales.columns
# Out:
# Index(['country_cd', 'channel', 'customer', 'inventory_location', 'SKU_Number',
#        'transaction_date', 'sales_typ', 'sales_qty', 'local_crncy',
#        'sls_val_loc_crncy', 'src_sls_usd', 'whse_cntry_cd', 'ship_whse_cd',
#        'sls_cntry_cd', 'frc_cd', 'consign_cntry', 'shipto_cntry', 'cust_catg',
#        'cust_catg_lvl1', 'cust_catg_lvl2', 'cust_nbr', 'batch_lot_nbr',
#        'qty_ordr', 'ordr_nbr', 'req_ship_dt', 'ordr_create_dt', 'create_date'],
#       dtype='object')

# %%
#finally checking the whethere any column having null valye or not
sales.isnull()
# Out:
#         country_cd  channel  customer  inventory_location  SKU_Number  \
# 0            False    False     False               False       False
# 1            False    False     False               False       False
# 2            False    False     False               False       False
# 3            False    False     False               False       False
# 4            False    False     False               False       False
# ...            ...      ...       ...                 ...         ...
# 999995       False    False     False               False       False
# 999996       False    False     False               False       False
# 999997       False    False     False               False       False
# 999998       False    False     False               False       False
# 999999       False    False     False               False       False
#
#         transaction_date  sales_typ  sales_qty  local_crncy  \
# 0                  False      False      False        False
# ...

# %%
#checking null values in cust catg lvl2 column 

sales['cust_catg_lvl2'].isnull().sum()
# Out:
# 1000000

# %%
#droppng the cust cat column 

sales.drop('cust_catg_lvl2',axis=1,inplace=True)

# %%
#dropping the cust_catg_lvl1 column

sales.drop('cust_catg_lvl1',axis=1,inplace=True)

# %%
#checking null values count 

sales.isnull().sum()
# Out:
# country_cd                  0
# channel                     0
# customer                    0
# inventory_location          0
# SKU_Number                  0
# transaction_date            0
# sales_typ                   0
# sales_qty                   0
# local_crncy                 0
# sls_val_loc_crncy           0
# src_sls_usd                 0
# whse_cntry_cd               0
# ship_whse_cd                1
# sls_cntry_cd                0
# frc_cd                1000000
# consign_cntry               0
# shipto_cntry                0
# cust_catg                   0
# cust_nbr                    0
# batch_lot_nbr               0
# qty_ordr                    0
# ordr_nbr                    0
# req_ship_dt                 0
# ordr_create_dt              0
# create_date                 0
# dtype: int64

# %%
#checking null values count  frc cd 

sales['frc_cd'].isnull().count()
# Out:
# 1000000

# %%
#dropping the frc cd column

sales.drop('frc_cd',axis=1,inplace=True)

# %%
sales.isnull().sum()
# Out:
# country_cd            0
# channel               0
# customer              0
# inventory_location    0
# SKU_Number            0
# transaction_date      0
# sales_typ             0
# sales_qty             0
# local_crncy           0
# sls_val_loc_crncy     0
# src_sls_usd           0
# whse_cntry_cd         0
# ship_whse_cd          1
# sls_cntry_cd          0
# consign_cntry         0
# shipto_cntry          0
# cust_catg             0
# cust_nbr              0
# batch_lot_nbr         0
# qty_ordr              0
# ordr_nbr              0
# req_ship_dt           0
# ordr_create_dt        0
# create_date           0
# dtype: int64

# %%
#checking NAN values in dataset 

sales.isna().sum()
# Out:
# country_cd            0
# channel               0
# customer              0
# inventory_location    0
# SKU_Number            0
# transaction_date      0
# sales_typ             0
# sales_qty             0
# local_crncy           0
# sls_val_loc_crncy     0
# src_sls_usd           0
# whse_cntry_cd         0
# ship_whse_cd          1
# sls_cntry_cd          0
# consign_cntry         0
# shipto_cntry          0
# cust_catg             0
# cust_nbr              0
# batch_lot_nbr         0
# qty_ordr              0
# ordr_nbr              0
# req_ship_dt           0
# ordr_create_dt        0
# create_date           0
# dtype: int64

# %%
#viewing the data cloumns its not having date only time is present

sales['create_date']
# Out:
# 0         49:13.0
# 1         49:13.1
# 2         49:13.1
# 3         49:13.1
# 4         49:13.1
#            ...
# 999995    53:44.8
# 999996    53:44.8
# 999997    53:44.8
# 999998    53:44.8
# 999999    53:44.8
# Name: create_date, Length: 1000000, dtype: object

# %%
#so we are dropping that column 

sales.drop('create_date',axis=1,inplace=True)

# %%
sales.head()
# Out:
#    country_cd channel                   customer  inventory_location  \
# 0          12   OTHER                Heiko Zobel                  98
# 1          15  DIRECT     Theres Trommler B.Eng.                  93
# 2          12  DIRECT     Dr. Helena Wähner MBA.                  98
# 3          13  DIRECT      Sylke Mülichen B.Eng.                  93
# 4          10   OTHER  Univ.Prof. Angelique Koch                  93
#
#   SKU_Number transaction_date sales_typ  sales_qty local_crncy  \
# 0   38753-97       09-07-2021    Return       7607         INR
# 1   70339-30       08-06-2021    Return       3430         INR
# 2   28088-72       08-09-2021    Return       4081         INR
# 3   10785-85       26-09-2021    Return        592         INR
# 4   17101-76       10-12-2021    Return       8745         INR
#
#    sls_val_loc_crncy  ...  sls_cntry_cd  consign_cntry shipto_cntry  \
# 0              49580  ...            98          India        India
# ...

# %%
#viewing top 5 rows in the dataset 

inventory.head()
# Out:
#    Unnamed: 0 inventory_date  inventory_location SKU_Number inventory_status  \
# 0           0     2021-02-01                  93   67538-25        ALLOCATED
# 1           1     2021-10-08                  91   28082-95        ALLOCATED
# 2           2     2021-09-13                  94   50503-79        ALLOCATED
# 3           3     2021-08-24                  97   19595-13      UNALLOCATED
# 4           4     2021-03-30                  96   21489-47        ALLOCATED
#
#    inventory_qty  whse_site_cd  ship_whse_cd  src_inv_sts batch_mfg_lot  \
# 0           3492            93             6    Allocated     VOWJRELS9
# 1           8653            91             8    Allocated     KMMSC5BB9
# 2           8432            94             1    Allocated     JWO8C133M
# 3           6469            97             7  Unallocated     OWT9WI99J
# 4           7735            96             5    Allocated     ZT7SRY8M4
#
#   expiry_date  bal_type  AVP         create_date
# ...

# %%
#cheking information abt the data
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          10000 non-null  int64
#  1   inventory_date      10000 non-null  datetime64[ns]
#  2   inventory_location  10000 non-null  int64
#  3   SKU_Number          10000 non-null  object
#  4   inventory_status    10000 non-null  object
#  5   inventory_qty       10000 non-null  int64
#  6   whse_site_cd        10000 non-null  int64
#  7   ship_whse_cd        10000 non-null  int64
#  8   src_inv_sts         10000 non-null  object
#  9   batch_mfg_lot       10000 non-null  object
#  10  expiry_date         8808 non-null   datetime64[ns]
#  11  bal_type            0 non-null      float64
#  12  AVP                 0 non-null      float64
#  13  create_date         10000 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), float64(2), int64(5), object(4)
# ...

# %%
inventory.describe()
# Out:
#         Unnamed: 0  inventory_location  inventory_qty  whse_site_cd  \
# count  10000.00000        10000.000000   10000.000000  10000.000000
# mean    4999.50000           94.519600    4991.010300     94.519600
# std     2886.89568            2.870442    2909.130648      2.870442
# min        0.00000           90.000000       1.000000     90.000000
# 25%     2499.75000           92.000000    2466.000000     92.000000
# 50%     4999.50000           94.000000    4992.500000     94.000000
# 75%     7499.25000           97.000000    7520.250000     97.000000
# max     9999.00000           99.000000   10000.000000     99.000000
#
#        ship_whse_cd  bal_type  AVP
# count  10000.000000       0.0  0.0
# mean       4.999600       NaN  NaN
# std        2.603628       NaN  NaN
# min        1.000000       NaN  NaN
# 25%        3.000000       NaN  NaN
# 50%        5.000000       NaN  NaN
# 75%        7.000000       NaN  NaN
# max        9.000000       NaN  NaN

# %%
#checking is null values in dataset 

inventory.isna()
# Out:
#       Unnamed: 0  inventory_date  inventory_location  SKU_Number  \
# 0          False           False               False       False
# 1          False           False               False       False
# 2          False           False               False       False
# 3          False           False               False       False
# 4          False           False               False       False
# ...          ...             ...                 ...         ...
# 9995       False           False               False       False
# 9996       False           False               False       False
# 9997       False           False               False       False
# 9998       False           False               False       False
# 9999       False           False               False       False
#
#       inventory_status  inventory_qty  whse_site_cd  ship_whse_cd  \
# 0                False          False         False         False
# ...

# %%
#counting total values in the column

inventory.count()
# Out:
# Unnamed: 0            10000
# inventory_date        10000
# inventory_location    10000
# SKU_Number            10000
# inventory_status      10000
# inventory_qty         10000
# whse_site_cd          10000
# ship_whse_cd          10000
# src_inv_sts           10000
# batch_mfg_lot         10000
# expiry_date            8808
# bal_type                  0
# AVP                       0
# create_date           10000
# dtype: int64

# %%
#dropping the unnamed column in dataset 

inventory.drop('Unnamed: 0' ,axis=1 ,inplace=True)

# %%
#checking how many null values in bal type column 

inventory['bal_type'].isnull().sum()
# Out:
# 10000

# %%
#dropping the bal type column 

inventory.drop('bal_type',axis=1,inplace=True)

# %%
#dropping the AVP column 

inventory.drop('AVP',axis=1,inplace=True)

# %%
inventory.columns
# Out:
# Index(['inventory_date', 'inventory_location', 'SKU_Number',
#        'inventory_status', 'inventory_qty', 'whse_site_cd', 'ship_whse_cd',
#        'src_inv_sts', 'batch_mfg_lot', 'expiry_date', 'create_date'],
#       dtype='object')

# %%
#dropping duplicate values in the dataset

inventory.drop_duplicates().count()
# Out:
# inventory_date        10000
# inventory_location    10000
# SKU_Number            10000
# inventory_status      10000
# inventory_qty         10000
# whse_site_cd          10000
# ship_whse_cd          10000
# src_inv_sts           10000
# batch_mfg_lot         10000
# expiry_date            8808
# create_date           10000
# dtype: int64

# %%
#checking is null values count in each column 

inventory.isna().sum()
# Out:
# inventory_date           0
# inventory_location       0
# SKU_Number               0
# inventory_status         0
# inventory_qty            0
# whse_site_cd             0
# ship_whse_cd             0
# src_inv_sts              0
# batch_mfg_lot            0
# expiry_date           1192
# create_date              0
# dtype: int64

# %%
inventory['expiry_date'].fillna(method='ffill',inplace=True)

# %%
inventory.isna().sum()
# Out:
# inventory_date        0
# inventory_location    0
# SKU_Number            0
# inventory_status      0
# inventory_qty         0
# whse_site_cd          0
# ship_whse_cd          0
# src_inv_sts           0
# batch_mfg_lot         0
# expiry_date           0
# create_date           0
# dtype: int64

# %%
inventory.head()
# Out:
#   inventory_date  inventory_location SKU_Number inventory_status  \
# 0     2021-02-01                  93   67538-25        ALLOCATED
# 1     2021-10-08                  91   28082-95        ALLOCATED
# 2     2021-09-13                  94   50503-79        ALLOCATED
# 3     2021-08-24                  97   19595-13      UNALLOCATED
# 4     2021-03-30                  96   21489-47        ALLOCATED
#
#    inventory_qty  whse_site_cd  ship_whse_cd  src_inv_sts batch_mfg_lot  \
# 0           3492            93             6    Allocated     VOWJRELS9
# 1           8653            91             8    Allocated     KMMSC5BB9
# 2           8432            94             1    Allocated     JWO8C133M
# 3           6469            97             7  Unallocated     OWT9WI99J
# 4           7735            96             5    Allocated     ZT7SRY8M4
#
#   expiry_date         create_date
# 0  2022-05-01 2023-05-04 14:45:00
# 1  2022-05-31 2023-05-04 14:45:00
# 2  2022-07-02 2023-05-04 14:45:00
# ...

# %%
inventory['create_date']
# Out:
# 0      2023-05-04 14:45:00
# 1      2023-05-04 14:45:00
# 2      2023-05-04 14:45:00
# 3      2023-05-04 14:45:00
# 4      2023-05-04 14:45:00
#                ...
# 9995   2023-05-04 14:45:00
# 9996   2023-05-04 14:45:00
# 9997   2023-05-04 14:45:00
# 9998   2023-05-04 14:45:00
# 9999   2023-05-04 14:45:00
# Name: create_date, Length: 10000, dtype: datetime64[ns]

# %%
inventory['create_date']=pd.to_datetime(inventory['create_date']).dt.date

# %%
sales.head()
# Out:
#    country_cd channel                   customer  inventory_location  \
# 0          12   OTHER                Heiko Zobel                  98
# 1          15  DIRECT     Theres Trommler B.Eng.                  93
# 2          12  DIRECT     Dr. Helena Wähner MBA.                  98
# 3          13  DIRECT      Sylke Mülichen B.Eng.                  93
# 4          10   OTHER  Univ.Prof. Angelique Koch                  93
#
#   SKU_Number transaction_date sales_typ  sales_qty local_crncy  \
# 0   38753-97       09-07-2021    Return       7607         INR
# 1   70339-30       08-06-2021    Return       3430         INR
# 2   28088-72       08-09-2021    Return       4081         INR
# 3   10785-85       26-09-2021    Return        592         INR
# 4   17101-76       10-12-2021    Return       8745         INR
#
#    sls_val_loc_crncy  ...  sls_cntry_cd  consign_cntry shipto_cntry  \
# 0              49580  ...            98          India        India
# ...

# %%
sb.pairplot(data='sales')
